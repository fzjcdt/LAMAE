# %%
import math
import numpy as np
import tensorflow as tf
from sklearn.metrics import roc_auc_score, average_precision_score
from sklearn.utils import shuffle
from tensorflow.keras import backend as K
from tensorflow.keras.activations import softmax, relu
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.datasets import mnist, fashion_mnist, cifar10
from tensorflow.keras.initializers import RandomUniform
from tensorflow.keras.layers import Dense, Conv2D, Input, Flatten, Conv2DTranspose, Reshape, BatchNormalization, ReLU, \
    Layer, GlobalAveragePooling2D, Concatenate, Add
from tensorflow.keras.models import Model, load_model
from skimage.measure import shannon_entropy

# %%
class LAMAECallback(Callback):
    def __init__(self, saved_model_name):
        super().__init__()   
        self.saved_model_name = saved_model_name
        
    def on_epoch_end(self, epoch, logs=None):
        # Save the model with minimal reconstruction error on the validation set
        x_val_recon, _ = self.model.predict(x_val)
        recon_err_mean = np.mean(np.square(x_val - x_val_recon))
        
        global min_recon_err
        if recon_err_mean < min_recon_err:
            min_recon_err = recon_err_mean
            self.model.save(self.saved_model_name)
            print('save model, epoch={}, recon_err_mean={}'.format(epoch, recon_err_mean, 2))

# %%
def compute_cosine_distances(a, b):
    """Calculate the cosine distance between a and b"""
    a_normalized, _ = tf.linalg.normalize(a, ord=1, axis=-1)
    b_normalized, _ = tf.linalg.normalize(b, ord=1, axis=-1)
    b_normalized_transposed = tf.transpose(b_normalized)
    distance = tf.matmul(a_normalized, b_normalized_transposed)
            
    return distance


class MemoryUnit(Layer):
    def __init__(self, class_num, block_size, name=None, **kwargs):
        super(MemoryUnit, self).__init__(name=name)
        self.class_num = class_num
        self.block_size = block_size
        super(MemoryUnit, self).__init__(**kwargs)
    
    def get_config(self):
        config = super(MemoryUnit, self).get_config()
        config.update({
            "class_num": self.class_num,
            "block_size": self.block_size})
        
        return config
    
    def build(self, input_shape):        
        # shape: (class_num x block_size, latent dim) = (M, L)
        self.weight = self.add_weight(shape=(self.class_num * self.block_size, input_shape[-1]),
                                      initializer=RandomUniform(-5, 5),
                                      trainable=True)

    def call(self, z, y):
        y = tf.where(tf.equal(tf.reduce_max(y, axis=1, keepdims=True), y),
                     tf.constant(1.0),
                     tf.constant(0.0))
        att_weight = tf.tile(y, [1, self.block_size])
        
        # z x Mem^T -> (batchxL) x (LxM) = batchxM
        sim_weight = compute_cosine_distances(z, self.weight) 
        
        com_weight = att_weight * sim_weight
        com_weight = softmax(com_weight)

        output = tf.matmul(com_weight, self.weight)
        return output

# %%
def get_lamae_model(input_shape=(28, 28, 1), 
                    channels=(32, 64), 
                    latent_dim=32, 
                    skip_dim=0, 
                    class_num=9, 
                    block_size=10):
    x_in = Input(shape=input_shape)
    x = x_in
    # encoder
    for c in channels:
        x = Conv2D(c, 3, 2, padding='same')(x)
        x = BatchNormalization()(x)
        x = ReLU()(x)

    shape = K.int_shape(x)
    x = Flatten()(x)
    
    z = Dense(latent_dim)(x)
    z = BatchNormalization()(z)
    
    if skip_dim != 0:
        sz = Dense(skip_dim)(z)
        sz = Dense(latent_dim)(sz)
    
    clf_out = Dense(class_num, activation='softmax', name='clf')(z)
    z = MemoryUnit(class_num, block_size)(z, clf_out)
    
    # skip connection
    if skip_dim != 0:
        z = Add()([z, sz])
    x = Dense(shape[1] * shape[2] * shape[3], activation='relu')(z)
    x = Reshape((shape[1], shape[2], shape[3]))(x)
    
    # decoder
    for c in channels[::-1]:
        x = Conv2DTranspose(c, 3, 2, padding='same')(x)
        x = BatchNormalization()(x)
        x = ReLU()(x)

    x_out = Conv2DTranspose(input_shape[2], 3, activation='sigmoid', padding='same', name='recon')(x)

    model = Model(x_in, [x_out, clf_out])

    model.compile(optimizer='adam', loss={'recon': 'mse', 'clf': 'sparse_categorical_crossentropy'})

    return model

# %% [markdown]
# # Mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape((60000, 28, 28, 1)) / 255.0
x_test = x_test.reshape((10000, 28, 28, 1)) / 255.0
print(x_train.shape)
print(x_test.shape)


def handle_data(ood_class: int):
    # id = 1, ood = -1
    index = np.array([e != ood_class for e in y_train])
    new_x_train, new_y_train = x_train[index], y_train[index]
    for i in range(len(new_y_train)):
        new_y_train[i] = new_y_train[i] - 1 if new_y_train[i] > ood_class else new_y_train[i]
    
    new_ood_x_test_1 = x_train[index == False]
    
    index = np.array([e != ood_class for e in y_test])
    new_ood_x_test_2 = x_test[index == False]
    new_ood_x_test = list(new_ood_x_test_1) + list(new_ood_x_test_2)
    new_id_x_test = x_test[index][:len(new_ood_x_test)]
    
    new_x_test = np.array(list(new_id_x_test) + list(new_ood_x_test))
    new_y_test = np.array([1 for _ in range(len(new_id_x_test))] + [-1 for _ in range(len(new_ood_x_test))])
    new_x_test, new_y_test = shuffle(new_x_test, new_y_test)
    
    # new_y_train：[0,1,...,8], new_y_test: {-1, 1}
    return new_x_train, new_y_train, new_x_test, new_y_test
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
for ood_class in range(10):
    new_x_train, new_y_train, new_x_test, new_y_test = handle_data(ood_class)
    x_val = new_x_train[50000:]
    y_val = new_y_train[50000:]
    new_x_train = new_x_train[:50000]
    new_y_train = new_y_train[:50000]
    for ite in range(1):
        print('*' * 30, 'ood={}, ite={}'.format(ood_class, ite), '*' * 30)
        saved_model_name = './saved_model/mnist_ood{}_ite{}.h5'.format(ood_class, ite)

        min_recon_err = float('inf')
        model = get_lamae_model()
        model.fit(new_x_train, {'recon': new_x_train, 'clf': new_y_train},
              shuffle=True,
              epochs=200,
              batch_size=128,
              verbose=0,
              callbacks = [LAMAECallback(saved_model_name)])
        
        # Testing
        model = load_model(saved_model_name, custom_objects={'MemoryUnit': MemoryUnit})        
        x_test_recon, _ = model.predict(new_x_test)
        recon_err = np.mean(np.square(new_x_test - x_test_recon), axis=(1, 2, 3))
        
        # LAMAE
        auroc = round(100 * roc_auc_score(new_y_test, -recon_err), 2)
        auprc = round(100 * average_precision_score(new_y_test, -recon_err), 2)
        print('LAMAE test set, ood={}, ite={}, auroc={}%, auprc={}%'.format(ood_class, ite, auroc, auprc))
        
        # LAMAE+
        entropys = np.array([shannon_entropy(e) for e in new_x_test])
        sigma = 1e-9
        auroc = round(100 * roc_auc_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
        auprc = round(100 * average_precision_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
        print('LAMAE+ test set, ood={}, ite={}, auroc={}%, auprc={}%'.format(ood_class, ite, auroc, auprc))
        print()
# Out:
# ****************************** ood=0, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07304661010102313
# save model, epoch=1, recon_err_mean=0.06439831797065132
# save model, epoch=2, recon_err_mean=0.06438556842932208
# save model, epoch=4, recon_err_mean=0.06434732218505604
# save model, epoch=6, recon_err_mean=0.06434575164646973
# save model, epoch=8, recon_err_mean=0.06429845968085995
# save model, epoch=10, recon_err_mean=0.062117923859081485
# save model, epoch=11, recon_err_mean=0.05589562052728274
# save model, epoch=12, recon_err_mean=0.05273641010001821
# save model, epoch=18, recon_err_mean=0.0523946469219118
# save model, epoch=23, recon_err_mean=0.05007775427277692
# save model, epoch=30, recon_err_mean=0.039101891806901615
# save model, epoch=39, recon_err_mean=0.03816913532914424
# save model, epoch=46, recon_err_mean=0.037245903512328704
# save model, epoch=48, recon_err_mean=0.03567006885536443
# save model, epoch=54, recon_err_mean=0.03383220303225055
# save model, epoch=55, recon_err_mean=0.03030868579991729
# save model, epoch=62, recon_err_mean=0.02972808006376795
# save model, epoch=64, recon_err_mean=0.02759306871477548
# save model, epoch=79, recon_err_mean=0.025697707326925254
# save model, epoch=100, recon_err_mean=0.02464802792861026
# save model, epoch=115, recon_err_mean=0.024440681121430396
# save model, epoch=118, recon_err_mean=0.022217868704995508
# save model, epoch=128, recon_err_mean=0.021879069507365883
# save model, epoch=132, recon_err_mean=0.020883227037601686
# save model, epoch=150, recon_err_mean=0.02001448473151279
# save model, epoch=154, recon_err_mean=0.019576543103924836
# save model, epoch=164, recon_err_mean=0.018730602324244585
# save model, epoch=199, recon_err_mean=0.018453697993745872
# LAMAE test set, ood=0, ite=0, auroc=99.04%, auprc=99.24%
# LAMAE+ test set, ood=0, ite=0, auroc=98.61%, auprc=98.92%
#
# ****************************** ood=1, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07750593176892309
# save model, epoch=1, recon_err_mean=0.06875840419741612
# save model, epoch=6, recon_err_mean=0.06870575737997689
# save model, epoch=7, recon_err_mean=0.06870469517018864
# save model, epoch=8, recon_err_mean=0.068631721896443
# save model, epoch=9, recon_err_mean=0.057439988841084914
# save model, epoch=10, recon_err_mean=0.0500589895702594
# save model, epoch=14, recon_err_mean=0.04715245985513757
# save model, epoch=26, recon_err_mean=0.04318631848850821
# save model, epoch=30, recon_err_mean=0.04121759645430619
# save model, epoch=33, recon_err_mean=0.03963340874725184
# save model, epoch=41, recon_err_mean=0.034242409091911556
# save model, epoch=42, recon_err_mean=0.033608985276092185
# save model, epoch=47, recon_err_mean=0.03032680492624987
# save model, epoch=51, recon_err_mean=0.029388611446669443
# save model, epoch=58, recon_err_mean=0.02834308933961084
# save model, epoch=67, recon_err_mean=0.025255656199597555
# save model, epoch=73, recon_err_mean=0.024769577565965407
# save model, epoch=76, recon_err_mean=0.024400548578701428
# save model, epoch=79, recon_err_mean=0.0234609164840378
# save model, epoch=84, recon_err_mean=0.02154725308845741
# save model, epoch=89, recon_err_mean=0.021409375669566823
# save model, epoch=102, recon_err_mean=0.020948109652980138
# save model, epoch=112, recon_err_mean=0.02026825254462917
# save model, epoch=115, recon_err_mean=0.020061123452648284
# save model, epoch=119, recon_err_mean=0.019657629174127215
# save model, epoch=124, recon_err_mean=0.019437510803669247
# save model, epoch=131, recon_err_mean=0.019411349670619662
# save model, epoch=134, recon_err_mean=0.019185892696197932
# save model, epoch=142, recon_err_mean=0.01851429254731404
# save model, epoch=162, recon_err_mean=0.018201596857148155
# save model, epoch=194, recon_err_mean=0.017631744368848627
# LAMAE test set, ood=1, ite=0, auroc=72.42%, auprc=78.63%
# LAMAE+ test set, ood=1, ite=0, auroc=90.22%, auprc=92.26%
#
# ****************************** ood=2, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07391149417465757
# save model, epoch=1, recon_err_mean=0.06569272613388376
# save model, epoch=2, recon_err_mean=0.06566248904687741
# save model, epoch=4, recon_err_mean=0.06563072293181647
# save model, epoch=6, recon_err_mean=0.065617895996445
# save model, epoch=7, recon_err_mean=0.06029335665104089
# save model, epoch=9, recon_err_mean=0.05356716115371255
# save model, epoch=11, recon_err_mean=0.05026374539022568
# save model, epoch=12, recon_err_mean=0.041489289119330836
# save model, epoch=24, recon_err_mean=0.039640001909714354
# save model, epoch=39, recon_err_mean=0.0327655849276644
# save model, epoch=48, recon_err_mean=0.03098551495227925
# save model, epoch=50, recon_err_mean=0.028231430527362825
# save model, epoch=58, recon_err_mean=0.028225709130522407
# save model, epoch=64, recon_err_mean=0.026924841023933853
# save model, epoch=68, recon_err_mean=0.025499850535899857
# save model, epoch=70, recon_err_mean=0.023022423070186412
# save model, epoch=76, recon_err_mean=0.020327459093473912
# save model, epoch=89, recon_err_mean=0.019313879776899957
# save model, epoch=107, recon_err_mean=0.019306221217243624
# save model, epoch=112, recon_err_mean=0.01862856941375051
# save model, epoch=114, recon_err_mean=0.018346347979041746
# save model, epoch=122, recon_err_mean=0.01715416746795172
# save model, epoch=142, recon_err_mean=0.01693747882366534
# save model, epoch=143, recon_err_mean=0.016673060133810216
# save model, epoch=171, recon_err_mean=0.01651989706040434
# save model, epoch=180, recon_err_mean=0.015718233299105995
# save model, epoch=196, recon_err_mean=0.015590038846515006
# LAMAE test set, ood=2, ite=0, auroc=98.94%, auprc=99.09%
# LAMAE+ test set, ood=2, ite=0, auroc=99.04%, auprc=99.21%
#
# ****************************** ood=3, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07504557863982968
# save model, epoch=1, recon_err_mean=0.0665340335637239
# save model, epoch=3, recon_err_mean=0.06652594111296044
# save model, epoch=5, recon_err_mean=0.06651799360139865
# save model, epoch=6, recon_err_mean=0.06647123007894938
# save model, epoch=10, recon_err_mean=0.066435891713115
# save model, epoch=13, recon_err_mean=0.052648751570064024
# save model, epoch=14, recon_err_mean=0.04496647912979833
# save model, epoch=19, recon_err_mean=0.04151554328857636
# save model, epoch=30, recon_err_mean=0.04127669441126692
# save model, epoch=36, recon_err_mean=0.03821996613613758
# save model, epoch=43, recon_err_mean=0.030568234879351706
# save model, epoch=52, recon_err_mean=0.02946423309091598
# save model, epoch=62, recon_err_mean=0.025187955527738448
# save model, epoch=65, recon_err_mean=0.02422223556990301
# save model, epoch=73, recon_err_mean=0.022960367966525192
# save model, epoch=82, recon_err_mean=0.02268064602776804
# save model, epoch=89, recon_err_mean=0.019941233399188345
# save model, epoch=106, recon_err_mean=0.01980911420067265
# save model, epoch=116, recon_err_mean=0.01943095375568633
# save model, epoch=117, recon_err_mean=0.01860880869783874
# save model, epoch=120, recon_err_mean=0.018375810694362095
# save model, epoch=122, recon_err_mean=0.01809015228574869
# save model, epoch=123, recon_err_mean=0.017886890070820068
# save model, epoch=141, recon_err_mean=0.017703981247450894
# save model, epoch=148, recon_err_mean=0.017293297096134287
# save model, epoch=154, recon_err_mean=0.01715239661761608
# save model, epoch=165, recon_err_mean=0.0165722953173283
# save model, epoch=193, recon_err_mean=0.016271306597273345
# LAMAE test set, ood=3, ite=0, auroc=97.98%, auprc=98.36%
# LAMAE+ test set, ood=3, ite=0, auroc=98.1%, auprc=98.56%
#
# ****************************** ood=4, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.08124216475009527
# save model, epoch=1, recon_err_mean=0.06760425352882367
# save model, epoch=6, recon_err_mean=0.06755017765204968
# save model, epoch=8, recon_err_mean=0.0674570040156697
# save model, epoch=9, recon_err_mean=0.06624305647561496
# save model, epoch=10, recon_err_mean=0.057531342709482354
# save model, epoch=11, recon_err_mean=0.04591694462719346
# save model, epoch=19, recon_err_mean=0.04131819169903084
# save model, epoch=33, recon_err_mean=0.036083989680434574
# save model, epoch=35, recon_err_mean=0.0346103078250738
# save model, epoch=38, recon_err_mean=0.03204514246126983
# save model, epoch=42, recon_err_mean=0.027877750996571908
# save model, epoch=53, recon_err_mean=0.02490018672317298
# save model, epoch=63, recon_err_mean=0.02431809533921181
# save model, epoch=70, recon_err_mean=0.023469721182953467
# save model, epoch=73, recon_err_mean=0.02344716367869373
# save model, epoch=74, recon_err_mean=0.022827300066972235
# save model, epoch=88, recon_err_mean=0.022404116831196058
# save model, epoch=90, recon_err_mean=0.021693687409311883
# save model, epoch=92, recon_err_mean=0.020819841653785063
# save model, epoch=93, recon_err_mean=0.02014513450038573
# save model, epoch=94, recon_err_mean=0.019977353165798854
# save model, epoch=112, recon_err_mean=0.01985237892409896
# save model, epoch=117, recon_err_mean=0.019571017807680266
# save model, epoch=123, recon_err_mean=0.01914541652049515
# save model, epoch=134, recon_err_mean=0.018816083604440502
# save model, epoch=135, recon_err_mean=0.01837821801127934
# save model, epoch=136, recon_err_mean=0.01808056687253058
# save model, epoch=145, recon_err_mean=0.018080413871558555
# save model, epoch=149, recon_err_mean=0.017750136650841398
# save model, epoch=151, recon_err_mean=0.017162114779355368
# save model, epoch=167, recon_err_mean=0.016916753202189983
# save model, epoch=187, recon_err_mean=0.016671889498661448
# save model, epoch=190, recon_err_mean=0.01611391458322556
# LAMAE test set, ood=4, ite=0, auroc=93.58%, auprc=94.48%
# LAMAE+ test set, ood=4, ite=0, auroc=95.24%, auprc=96.06%
#
# ****************************** ood=5, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07610615294583803
# save model, epoch=1, recon_err_mean=0.06712093961888213
# save model, epoch=2, recon_err_mean=0.06710507601780338
# save model, epoch=3, recon_err_mean=0.06707319981027744
# save model, epoch=4, recon_err_mean=0.06705414528020827
# save model, epoch=6, recon_err_mean=0.067042822430822
# save model, epoch=7, recon_err_mean=0.06699788303855547
# save model, epoch=8, recon_err_mean=0.06697872425969763
# save model, epoch=10, recon_err_mean=0.05147430830140547
# save model, epoch=14, recon_err_mean=0.04228614480523088
# save model, epoch=21, recon_err_mean=0.03858916504587124
# save model, epoch=27, recon_err_mean=0.03651546172520114
# save model, epoch=33, recon_err_mean=0.03144108389604372
# save model, epoch=38, recon_err_mean=0.028751243307406815
# save model, epoch=40, recon_err_mean=0.027761611141659055
# save model, epoch=50, recon_err_mean=0.02263309280223704
# save model, epoch=64, recon_err_mean=0.02198276797081576
# save model, epoch=65, recon_err_mean=0.0212166340201503
# save model, epoch=70, recon_err_mean=0.02064042206005446
# save model, epoch=76, recon_err_mean=0.01992127407147713
# save model, epoch=82, recon_err_mean=0.019290534574757257
# save model, epoch=89, recon_err_mean=0.018921266559073953
# save model, epoch=94, recon_err_mean=0.018034964710667414
# save model, epoch=106, recon_err_mean=0.017623856644888462
# save model, epoch=117, recon_err_mean=0.01681519848246747
# save model, epoch=126, recon_err_mean=0.01655765976259728
# save model, epoch=143, recon_err_mean=0.016537715017261263
# save model, epoch=155, recon_err_mean=0.015715206797075783
# save model, epoch=189, recon_err_mean=0.015287444838322398
# save model, epoch=197, recon_err_mean=0.015107583886160595
# LAMAE test set, ood=5, ite=0, auroc=97.27%, auprc=97.82%
# LAMAE+ test set, ood=5, ite=0, auroc=97.59%, auprc=98.15%
#
# ****************************** ood=6, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07876353851579457
# save model, epoch=1, recon_err_mean=0.06684080438854538
# save model, epoch=7, recon_err_mean=0.06680818678641504
# save model, epoch=11, recon_err_mean=0.06680160735757902
# save model, epoch=12, recon_err_mean=0.06679561992908982
# save model, epoch=13, recon_err_mean=0.06676304024775287
# save model, epoch=14, recon_err_mean=0.0667075486373617
# save model, epoch=17, recon_err_mean=0.05074116963486992
# save model, epoch=18, recon_err_mean=0.04803270716204929
# save model, epoch=25, recon_err_mean=0.04690907480441058
# save model, epoch=33, recon_err_mean=0.0459243256377155
# save model, epoch=38, recon_err_mean=0.043349834327206814
# save model, epoch=42, recon_err_mean=0.040675682840093756
# save model, epoch=43, recon_err_mean=0.03584433424923241
# save model, epoch=48, recon_err_mean=0.03174279562439617
# save model, epoch=60, recon_err_mean=0.02647306993468485
# save model, epoch=72, recon_err_mean=0.02556831135263905
# save model, epoch=80, recon_err_mean=0.023075023219371677
# save model, epoch=98, recon_err_mean=0.023069005778109268
# save model, epoch=100, recon_err_mean=0.020932418264149925
# save model, epoch=113, recon_err_mean=0.020569485091881123
# save model, epoch=118, recon_err_mean=0.01985687907687274
# save model, epoch=130, recon_err_mean=0.019331806784508847
# save model, epoch=153, recon_err_mean=0.018251322311481143
# save model, epoch=158, recon_err_mean=0.018192866740063287
# save model, epoch=169, recon_err_mean=0.01818190594529378
# save model, epoch=177, recon_err_mean=0.018052801693559915
# save model, epoch=178, recon_err_mean=0.017521739429988074
# save model, epoch=192, recon_err_mean=0.017412692490671254
# LAMAE test set, ood=6, ite=0, auroc=95.4%, auprc=95.99%
# LAMAE+ test set, ood=6, ite=0, auroc=96.05%, auprc=96.63%
#
# ****************************** ood=7, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.07592250901417305
# save model, epoch=1, recon_err_mean=0.06727771257960179
# save model, epoch=3, recon_err_mean=0.0671404562546327
# save model, epoch=5, recon_err_mean=0.058592218419615774
# save model, epoch=6, recon_err_mean=0.05401850148544621
# save model, epoch=9, recon_err_mean=0.04858831476155686
# save model, epoch=10, recon_err_mean=0.04732276695897001
# save model, epoch=13, recon_err_mean=0.046990402738837
# save model, epoch=23, recon_err_mean=0.04586248890622685
# save model, epoch=24, recon_err_mean=0.045437533515141904
# save model, epoch=27, recon_err_mean=0.04078450426872848
# save model, epoch=29, recon_err_mean=0.03683441898215865
# save model, epoch=31, recon_err_mean=0.034623861760233986
# save model, epoch=38, recon_err_mean=0.02576894758212686
# save model, epoch=56, recon_err_mean=0.025631027352701192
# save model, epoch=62, recon_err_mean=0.02110985940168436
# save model, epoch=74, recon_err_mean=0.020434125130542602
# save model, epoch=93, recon_err_mean=0.02035039055484771
# save model, epoch=94, recon_err_mean=0.02010387049803397
# save model, epoch=101, recon_err_mean=0.019081210050650513
# save model, epoch=102, recon_err_mean=0.019069292049350792
# save model, epoch=106, recon_err_mean=0.018687433032752835
# save model, epoch=119, recon_err_mean=0.018023422386252732
# save model, epoch=126, recon_err_mean=0.01745157426664367
# save model, epoch=149, recon_err_mean=0.017349866954657102
# save model, epoch=157, recon_err_mean=0.017229959063477
# save model, epoch=158, recon_err_mean=0.016913519635300748
# save model, epoch=179, recon_err_mean=0.01674045554414444
# save model, epoch=193, recon_err_mean=0.016583120167380373
# save model, epoch=194, recon_err_mean=0.016582322311381566
# save model, epoch=195, recon_err_mean=0.0157698739688043
# LAMAE test set, ood=7, ite=0, auroc=92.84%, auprc=93.62%
# LAMAE+ test set, ood=7, ite=0, auroc=95.43%, auprc=96.08%
#
# ****************************** ood=8, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.08553693866515998
# save model, epoch=1, recon_err_mean=0.06734865487741595
# save model, epoch=2, recon_err_mean=0.06732398791080146
# save model, epoch=6, recon_err_mean=0.06723297498915404
# save model, epoch=9, recon_err_mean=0.05498330367496261
# save model, epoch=19, recon_err_mean=0.04581484569665578
# save model, epoch=29, recon_err_mean=0.042764561504357125
# save model, epoch=30, recon_err_mean=0.03936510858887003
# save model, epoch=43, recon_err_mean=0.03322745784698204
# save model, epoch=54, recon_err_mean=0.029734413817417326
# save model, epoch=58, recon_err_mean=0.029601087465002195
# save model, epoch=59, recon_err_mean=0.028745475068545592
# save model, epoch=61, recon_err_mean=0.025498848391086154
# save model, epoch=72, recon_err_mean=0.02293677806391559
# save model, epoch=83, recon_err_mean=0.022742710365908133
# save model, epoch=84, recon_err_mean=0.022388902508902533
# save model, epoch=85, recon_err_mean=0.022304600513775877
# save model, epoch=87, recon_err_mean=0.02204214537820739
# save model, epoch=91, recon_err_mean=0.02157740738596243
# save model, epoch=95, recon_err_mean=0.02040621832119869
# save model, epoch=98, recon_err_mean=0.018649069476635863
# save model, epoch=111, recon_err_mean=0.017932608134838875
# save model, epoch=123, recon_err_mean=0.017489046263264644
# save model, epoch=128, recon_err_mean=0.017467449936994707
# save model, epoch=130, recon_err_mean=0.01720763984906595
# save model, epoch=154, recon_err_mean=0.01693595714564324
# save model, epoch=164, recon_err_mean=0.016887437894140187
# save model, epoch=172, recon_err_mean=0.016733937168752353
# save model, epoch=179, recon_err_mean=0.01668523745025343
# save model, epoch=187, recon_err_mean=0.01571389654619901
# LAMAE test set, ood=8, ite=0, auroc=97.72%, auprc=98.19%
# LAMAE+ test set, ood=8, ite=0, auroc=97.24%, auprc=97.88%
#
# ****************************** ood=9, ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.08074594397010859
# save model, epoch=1, recon_err_mean=0.06830295269112212
# save model, epoch=3, recon_err_mean=0.06826479933430608
# save model, epoch=7, recon_err_mean=0.0682627951835856
# save model, epoch=8, recon_err_mean=0.06825595130066218
# save model, epoch=9, recon_err_mean=0.0682394882364115
# save model, epoch=11, recon_err_mean=0.06823538496015934
# save model, epoch=15, recon_err_mean=0.06819121746741792
# save model, epoch=17, recon_err_mean=0.06212452866089843
# save model, epoch=18, recon_err_mean=0.04937875400565368
# save model, epoch=19, recon_err_mean=0.04929636838712764
# save model, epoch=26, recon_err_mean=0.0452480423855729
# save model, epoch=31, recon_err_mean=0.04289482280557391
# save model, epoch=36, recon_err_mean=0.041518194053050655
# save model, epoch=43, recon_err_mean=0.03935055815846888
# save model, epoch=45, recon_err_mean=0.03726923864123029
# save model, epoch=49, recon_err_mean=0.036409816968724425
# save model, epoch=51, recon_err_mean=0.029415243141223138
# save model, epoch=58, recon_err_mean=0.02505323800943339
# save model, epoch=74, recon_err_mean=0.024958508240587644
# save model, epoch=78, recon_err_mean=0.024035061771346
# save model, epoch=80, recon_err_mean=0.02398069613521505
# save model, epoch=88, recon_err_mean=0.022366394977551197
# save model, epoch=92, recon_err_mean=0.021803934340772768
# save model, epoch=102, recon_err_mean=0.020035610259404372
# save model, epoch=112, recon_err_mean=0.019469353296097575
# save model, epoch=130, recon_err_mean=0.01846652658390195
# save model, epoch=131, recon_err_mean=0.018087306743694322
# save model, epoch=154, recon_err_mean=0.017929085190485358
# save model, epoch=156, recon_err_mean=0.017568680566409742
# save model, epoch=157, recon_err_mean=0.016949190457095496
# save model, epoch=185, recon_err_mean=0.016938917433524086
# save model, epoch=191, recon_err_mean=0.016511171320827793
# LAMAE test set, ood=9, ite=0, auroc=87.91%, auprc=90.03%
# LAMAE+ test set, ood=9, ite=0, auroc=90.14%, auprc=92.32%

# %% [markdown]
# # Fashion Mnist

# %%
(x_train, y_train), (id_x, _) = fashion_mnist.load_data()
x_train = x_train.reshape((60000, 28, 28, 1)) / 255.0
id_x = id_x.reshape((10000, 28, 28, 1)) / 255.0

x_val = x_train[50000:]
y_val = y_train[50000:]
new_x_train = x_train[:50000]
new_y_train = y_train[:50000]

(_, _), (ood_x, _) = mnist.load_data()
ood_x = ood_x.reshape((10000, 28, 28, 1)) / 255.0

new_x_test = np.array(list(id_x) + list(ood_x))
new_y_test = np.array([1 for _ in range(len(id_x))] + [-1 for _ in range(len(ood_x))])

for ite in range(1):
    print('*' * 30, 'ite={}'.format(ite), '*' * 30)
    saved_model_name = './saved_model/fashion_mnist_ite{}.h5'.format(ite)

    min_recon_err = float('inf')
    model = get_lamae_model(class_num=10)
    model.fit(new_x_train, {'recon': new_x_train, 'clf': new_y_train},
          shuffle=True,
          epochs=200,
          batch_size=128,
          verbose=0,
          callbacks = [LAMAECallback(saved_model_name)])

    # Testing
    model = load_model(saved_model_name, custom_objects={'MemoryUnit': MemoryUnit})        
    x_test_recon, _ = model.predict(new_x_test)
    recon_err = np.mean(np.square(new_x_test - x_test_recon), axis=(1, 2, 3))

    # LAMAE
    auroc = round(100 * roc_auc_score(new_y_test, -recon_err), 2)
    auprc = round(100 * average_precision_score(new_y_test, -recon_err), 2)
    print('LAMAE test set, ite={}, auroc={}%, auprc={}%'.format(ite, auroc, auprc))

    # LAMAE+
    entropys = np.array([shannon_entropy(e) for e in new_x_test])
    sigma = 1e-9
    auroc = round(100 * roc_auc_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
    auprc = round(100 * average_precision_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
    print('LAMAE+ test set, ite={}, auroc={}%, auprc={}%'.format(ite, auroc, auprc))
    print()
# Out:
# ****************************** ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.10740130426265644
# save model, epoch=1, recon_err_mean=0.08917269044603907
# save model, epoch=3, recon_err_mean=0.044029929882564225
# save model, epoch=9, recon_err_mean=0.0427236279861599
# save model, epoch=12, recon_err_mean=0.041053776987119255
# save model, epoch=15, recon_err_mean=0.0400308906560903
# save model, epoch=25, recon_err_mean=0.039979674336593406
# save model, epoch=31, recon_err_mean=0.03202413620805771
# save model, epoch=42, recon_err_mean=0.027136426937306543
# save model, epoch=51, recon_err_mean=0.026271429139769424
# save model, epoch=56, recon_err_mean=0.024075263515351372
# save model, epoch=59, recon_err_mean=0.024062929630682173
# save model, epoch=68, recon_err_mean=0.023059636714099503
# save model, epoch=71, recon_err_mean=0.022979406500009788
# save model, epoch=87, recon_err_mean=0.022644260849935566
# save model, epoch=89, recon_err_mean=0.02221079706781963
# save model, epoch=90, recon_err_mean=0.021811985347631815
# save model, epoch=102, recon_err_mean=0.021666949445698757
# save model, epoch=108, recon_err_mean=0.02134178993156308
# save model, epoch=111, recon_err_mean=0.021188240428689473
# save model, epoch=116, recon_err_mean=0.020668480039993428
# save model, epoch=126, recon_err_mean=0.0201804693231903
# save model, epoch=156, recon_err_mean=0.01984392214243511
# save model, epoch=191, recon_err_mean=0.019619831645636902
# LAMAE test set, ite=0, auroc=98.61%, auprc=98.95%
# LAMAE+ test set, ite=0, auroc=99.94%, auprc=99.95%

# %% [markdown]
# # CIFAR10

# %%
def handle_fashion(ood_x):
    # 28 * 28 -> 32 * 32 * 3
    images = []

    for t in range(len(ood_x)):
        img = np.zeros((32, 32, 3), dtype=int)
        for i in range(28):
            for j in range(28):
                img[i + 2][j + 2][0] = ood_x[t][i][j]
                img[i + 2][j + 2][1] = ood_x[t][i][j]
                img[i + 2][j + 2][2] = ood_x[t][i][j]
        img = img / 255.0
        images.append(img)

    return np.array(images)

# %%
(x_train, y_train), (id_x, _) = cifar10.load_data()
x_train, id_x = x_train / 255.0, id_x / 255.0
y_train = y_train.reshape(y_train.shape[0])

x_val = x_train[45000:]
y_val = y_train[45000:]
new_x_train = x_train[:45000]
new_y_train = y_train[:45000]

(_, _), (ood_x, _) = fashion_mnist.load_data()
ood_x = handle_fashion(ood_x)

new_x_test = np.array(list(id_x) + list(ood_x))
new_y_test = np.array([1 for _ in range(len(id_x))] + [-1 for _ in range(len(ood_x))])

for ite in range(1):
    print('*' * 30, 'ite={}'.format(ite), '*' * 30)
    saved_model_name = './saved_model/cifar10_ite{}.h5'.format(ite)

    min_recon_err = float('inf')
    model = get_lamae_model(input_shape=(32, 32, 3), 
                            channels=(64, 128, 128, 256), 
                            latent_dim=64, 
                            skip_dim=16, 
                            class_num=10, 
                            block_size=50)
    model.fit(new_x_train, {'recon': new_x_train, 'clf': new_y_train},
          shuffle=True,
          epochs=200,
          batch_size=128,
          verbose=0,
          callbacks = [LAMAECallback(saved_model_name)])

    # Testing
    model = load_model(saved_model_name, custom_objects={'MemoryUnit': MemoryUnit})        
    x_test_recon, _ = model.predict(new_x_test)
    recon_err = np.mean(np.square(new_x_test - x_test_recon), axis=(1, 2, 3))

    # LAMAE
    auroc = round(100 * roc_auc_score(new_y_test, -recon_err), 2)
    auprc = round(100 * average_precision_score(new_y_test, -recon_err), 2)
    print('LAMAE test set, ite={}, auroc={}%, auprc={}%'.format(ite, auroc, auprc))

    # LAMAE+
    entropys = np.array([shannon_entropy(e) for e in new_x_test])
    sigma = 1e-9
    auroc = round(100 * roc_auc_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
    auprc = round(100 * average_precision_score(new_y_test, -recon_err / (sigma + np.log(entropys + 1))), 2)
    print('LAMAE+ test set, ite={}, auroc={}%, auprc={}%'.format(ite, auroc, auprc))
    print()
# Out:
# ****************************** ite=0 ******************************
# save model, epoch=0, recon_err_mean=0.045423547576021316
# save model, epoch=1, recon_err_mean=0.02964047663231754
# save model, epoch=2, recon_err_mean=0.0271723156510119
# save model, epoch=6, recon_err_mean=0.026033273632340592
# save model, epoch=7, recon_err_mean=0.02571689254719984
# save model, epoch=8, recon_err_mean=0.02442935849129246
# save model, epoch=10, recon_err_mean=0.02429117083186729
# save model, epoch=11, recon_err_mean=0.024230629314131013
# save model, epoch=13, recon_err_mean=0.023326100364181663
# save model, epoch=18, recon_err_mean=0.022671189151649514
# save model, epoch=25, recon_err_mean=0.022185325189091304
# save model, epoch=28, recon_err_mean=0.021717012363867944
# save model, epoch=37, recon_err_mean=0.02142850466613022
# save model, epoch=43, recon_err_mean=0.021220117146877424
# save model, epoch=56, recon_err_mean=0.021129029082184586
# save model, epoch=57, recon_err_mean=0.021126819115736294
# save model, epoch=103, recon_err_mean=0.02110384510072151
# LAMAE test set, ite=0, auroc=84.01%, auprc=84.3%
# LAMAE+ test set, ite=0, auroc=95.16%, auprc=95.13%
